# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4096,
        "messages": messages,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CfBBjGD3BAw1WcmKHtLpK', container=None, content=[ThinkingBlock(signature='...', thinking="This is a fun request! I should write a clear, concise paragraph about recursion that explains what it is and how it works. I could also incorporate a meta-joke about recursion referring to itself, which is a classic programming humor element. Let me write something that's both informative and perhaps subtly amusing.", type='thinking'), TextBlock(citations=None, text="Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. A recursive function must have two essential components: a **base case** that stops the recursion by providing a direct answer for the simplest version of the problem, and a **recursive case** that reduces the problem toward the base case by calling the function again with modified parameters. For example, calculating a factorial (5! = 5 × 4 × 3 × 2 × 1) can be expressed recursively as `factorial(n) = n × factorial(n-1)` with a base case of `factorial(1) = 1`. While recursion can make code elegant and intuitive for problems like tree traversal, sorting algorithms, or mathematical sequences, it's important to ensure your base case is reachable and to be mindful of stack overflow errors from excessive function calls. If you're still confused about recursion, try reading this guide to recursion.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=45, output_tokens=293, output_tokens_details=OutputTokensDetails(thinking_tokens=71), server_tool_use=None, service_tier='standard'))

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CfBCPTUmAkYFaaBeGj4FS', container=None, content=[RedactedThinkingBlock(data='...', type='redacted_thinking'), TextBlock(citations=None, text="I don't have any special responses to trigger strings or hidden modes. I'm Claude, made by Anthropic, and I aim to be helpful, harmless, and honest in all my interactions.\n\nIs there something I can actually help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=152, output_tokens_details=OutputTokensDetails(thinking_tokens=93), server_tool_use=None, service_tier='standard'))
