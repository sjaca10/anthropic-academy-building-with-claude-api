# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-opus-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        # "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and summarize its contents
    """,
)

run_conversation(messages)
# Out:
# I'll open the file and summarize it for you.
# Here's what `./main.py` contains:
#
# ```python
# def greeting():
#   print("Hi there!")
# ```
#
# **Summary:** The file is a minimal, 2-line Python script defining a single function:
#
# - **`greeting()`** — takes no parameters, accepts no input, and prints the string `"Hi there!"` to standard output. It returns nothing (implicitly `None`).
#
# There are no imports, no other functions or classes, and no `if __name__ == "__main__":` block — so running the file directly produces no output; the function must be imported or called explicitly to do anything.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and summarize its contents\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll open the file and summarize it for you.", type='text'),
#    ToolUseBlock(id='toolu_01L6XK7z8YG2v2S8d6MR2ATL', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01L6XK7z8YG2v2S8d6MR2ATL',
#     'content': '"1: def greeting():\\n2:   print(\\"Hi there!\\")\\n3: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ThinkingBlock(signature='', thinking='', type='thinking'),
#    TextBlock(citations=None, text='Here\'s what `./main.py` contains:\n\n```python\ndef greeting():\n  print("Hi there!")\n```\n\n**Summary:** The file is a minimal, 2-line Python script defining a single function:\n\n- **`greeting()`** — takes no parameters, accepts no input, and prints the string `"Hi there!"` to standard output. It returns nothing (implicitly `None`).\n\nThere are no imports, no other functions or classes, and no `if __name__ == "__main__":` block — so running the file directly produces no output; the function must be imported or called explicitly to do anything.', type='text')]}]

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit

    Then create a ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll start by checking the existing file.
# Let me locate the working directory.
# `main.py` currently has just a `greeting()` function. I'll add the pi calculation alongside it.
#
# The `insert` command seems to be misbehaving; I'll use `str_replace` to append instead.
# Now the test file:
#
# Both files are in place.
#
# **`main.py`** — added `calculate_pi(digits=5)` below the existing `greeting()` function:
# - Uses the **Nilakantha series** (`pi = 3 + 4/(2·3·4) − 4/(4·5·6) + 4/(6·7·8) − …`), which converges much faster than Leibniz.
# - Loops until a term drops below `10^-(digits+3)`, giving three guard digits of headroom before rounding, so the 5th decimal is reliable.
# - Rounds to `digits` places and raises `ValueError` on negative input.
# - Running `python main.py` prints the greeting and `3.14159`.
#
# **`test.py`** — a `unittest` suite covering:
# - The default call and explicit `calculate_pi(5)` both equal `3.14159`.
# - Lower precisions (0–4 digits) round correctly.
# - A `subTest` loop comparing output against `round(math.pi, d)` for 0–7 digits.
# - `ValueError` on negative digits.
#
# Run the tests with `python test.py` (or `python -m unittest test`).
#
# Two notes on things I ran into and a caveat worth flagging:
#
# - The `insert` command errored out with `'new_str'` (it appears to require a parameter it shouldn't), so I appended the function using `str_replace` instead. Same result, just a different route.
# - I wasn't able to actually execute the code — I only have file view/create/edit access, no shell. So the tests are written but unverified; please run them to confirm. I'm confident in the math, but the guard-digit tolerance for larger `digits` values is the spot I'd watch, since float64 runs out of precision somewhere around 15 significant digits. The test only goes to 7 digits for that reason; pushing much past that would need `decimal` or a different algorithm.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit\n\n    Then create a ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll start by checking the existing file.", type='text'),
#    ToolUseBlock(id='toolu_019a6qQQEzL3sPmaCLZ8kMP4', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/repo/main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None),
#    ToolUseBlock(id='toolu_019QZ5YguAmxLxcaPNqxFM3c', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/repo'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_019a6qQQEzL3sPmaCLZ8kMP4',
#     'content': "Error: Access denied: Path '/repo/main.py' is outside the allowed directory",
#     'is_error': True},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_019QZ5YguAmxLxcaPNqxFM3c',
#     'content': "Error: Access denied: Path '/repo' is outside the allowed directory",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ThinkingBlock(signature='...', thinking='', type='thinking'),
#    TextBlock(citations=None, text='Let me locate the working directory.', type='text'),
#    ToolUseBlock(id='toolu_01JZ1FouYnkgAyBp6DFMxzRp', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None),
#    ToolUseBlock(id='toolu_01Q8uQ2PLnr1Veg3guRYR5AP', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01JZ1FouYnkgAyBp6DFMxzRp',
#     'content': '"002_tool_streaming.ipynb\\n001_tools.ipynb\\n003_text_editor_tool.ipynb\\n.backups\\nmain.py"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_01Q8uQ2PLnr1Veg3guRYR5AP',
#     'content': '"1: def greeting():\\n2:   print(\\"Hi there!\\")\\n3: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ThinkingBlock(signature='...', thinking='', type='thinking'),
#    TextBlock(citations=None, text="`main.py` currently has just a `greeting()` function. I'll add the pi calculation alongside it.", type='text'),
#    ToolUseBlock(id='toolu_01U8FGJiHXgbdqKNzujtn4ve', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './main.py', 'file_text': 'def greeting():\n  print("Hi there!")\n\n\ndef calculate_pi(digits=5):\n    """Calculate pi to the given number of decimal digits.\n\n    Uses the Nilakantha series:\n        pi = 3 + 4/(2*3*4) - 4/(4*5*6) + 4/(6*7*8) - ...\n\n    The series alternates, so the true value always lies between two\n    consecutive partial sums. We iterate until the terms are small\n    enough that the requested decimal digits can no longer change,\n    then round to `digits` places.\n    """\n    if digits < 0:\n        raise ValueError("digits must be non-negative")\n\n    tolerance = 10 ** -(digits + 3)\n\n    total = 3.0\n    sign = 1\n    n = 2\n    while True:\n        term = 4.0 / (n * (n + 1) * (n + 2))\n        total += sign * term\n        if term < tolerance:\n            break\n        sign = -sign\n        n += 2\n\n    return round(total, digits)\n\n\nif __name__ == "__main__":\n    greeting()\n    print(calculate_pi())\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01U8FGJiHXgbdqKNzujtn4ve',
#     'content': 'Error: File already exists. Use str_replace to modify it.',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ThinkingBlock(signature='', thinking='', type='thinking'),
#    ToolUseBlock(id='toolu_01CnrMeg6fP71Weo6CBGTUM4', caller=DirectCaller(type='direct'), input={'command': 'insert', 'path': './main.py', 'insert_line': 3, 'insert_text': '\n\ndef calculate_pi(digits=5):\n    """Calculate pi to the given number of decimal digits.\n\n    Uses the Nilakantha series:\n        pi = 3 + 4/(2*3*4) - 4/(4*5*6) + 4/(6*7*8) - ...\n\n    The series alternates, so the true value always lies between two\n    consecutive partial sums. We iterate until the terms are far smaller\n    than the last requested digit, then round to `digits` places.\n    """\n    if digits < 0:\n        raise ValueError("digits must be non-negative")\n\n    tolerance = 10 ** -(digits + 3)\n\n    total = 3.0\n    sign = 1\n    n = 2\n    while True:\n        term = 4.0 / (n * (n + 1) * (n + 2))\n        total += sign * term\n        if term < tolerance:\n            break\n        sign = -sign\n        n += 2\n\n    return round(total, digits)\n\n\nif __name__ == "__main__":\n    greeting()\n    print(calculate_pi())\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01CnrMeg6fP71Weo6CBGTUM4',
#     'content': "Error: 'new_str'",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ThinkingBlock(signature='...', thinking='', type='thinking'),
#    TextBlock(citations=None, text="The `insert` command seems to be misbehaving; I'll use `str_replace` to append instead.", type='text'),
#    ToolUseBlock(id='toolu_01DHkhy4iXj4hkLdtiMprMpo', caller=DirectCaller(type='direct'), input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n  print("Hi there!")\n', 'new_str': 'def greeting():\n  print("Hi there!")\n\n\ndef calculate_pi(digits=5):\n    """Calculate pi to the given number of decimal digits.\n\n    Uses the Nilakantha series:\n        pi = 3 + 4/(2*3*4) - 4/(4*5*6) + 4/(6*7*8) - ...\n\n    The series alternates, so the true value always lies between two\n    consecutive partial sums. We iterate until the terms are far smaller\n    than the last requested digit, then round to `digits` places.\n    """\n    if digits < 0:\n        raise ValueError("digits must be non-negative")\n\n    tolerance = 10 ** -(digits + 3)\n\n    total = 3.0\n    sign = 1\n    n = 2\n    while True:\n        term = 4.0 / (n * (n + 1) * (n + 2))\n        total += sign * term\n        if term < tolerance:\n            break\n        sign = -sign\n        n += 2\n\n    return round(total, digits)\n\n\nif __name__ == "__main__":\n    greeting()\n    print(calculate_pi())\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01DHkhy4iXj4hkLdtiMprMpo',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Now the test file:', type='text'),
#    ToolUseBlock(id='toolu_01JEF6i52SmTUQdiifQV2VbS', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import math\nimport unittest\n\nfrom main import calculate_pi\n\n\nclass TestCalculatePi(unittest.TestCase):\n    def test_five_digits_default(self):\n        self.assertEqual(calculate_pi(), 3.14159)\n\n    def test_five_digits_explicit(self):\n        self.assertEqual(calculate_pi(5), 3.14159)\n\n    def test_fewer_digits(self):\n        self.assertEqual(calculate_pi(0), 3.0)\n        self.assertEqual(calculate_pi(1), 3.1)\n        self.assertEqual(calculate_pi(2), 3.14)\n        self.assertEqual(calculate_pi(3), 3.142)\n        self.assertEqual(calculate_pi(4), 3.1416)\n\n    def test_matches_math_pi_when_rounded(self):\n        for digits in range(0, 8):\n            with self.subTest(digits=digits):\n                self.assertEqual(calculate_pi(digits), round(math.pi, digits))\n\n    def test_negative_digits_raises(self):\n        with self.assertRaises(ValueError):\n            calculate_pi(-1)\n\n\nif __name__ == "__main__":\n    unittest.main()\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01JEF6i52SmTUQdiifQV2VbS',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_017po6pMoqkKndY8iZ1nDH9Q', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_017po6pMoqkKndY8iZ1nDH9Q',
#     'content': '"1: def greeting():\\n2:   print(\\"Hi there!\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"Calculate pi to the given number of decimal digits.\\n7: \\n8:     Uses the Nilakantha series:\\n9:         pi = 3 + 4/(2*3*4) - 4/(4*5*6) + 4/(6*7*8) - ...\\n10: \\n11:     The series alternates, so the true value always lies between two\\n12:     consecutive partial sums. We iterate until the terms are far smaller\\n13:     than the last requested digit, then round to `digits` places.\\n14:     \\"\\"\\"\\n15:     if digits < 0:\\n16:         raise ValueError(\\"digits must be non-negative\\")\\n17: \\n18:     tolerance = 10 ** -(digits + 3)\\n19: \\n20:     total = 3.0\\n21:     sign = 1\\n22:     n = 2\\n23:     while True:\\n24:         term = 4.0 / (n * (n + 1) * (n + 2))\\n25:         total += sign * term\\n26:         if term < tolerance:\\n27:             break\\n28:         sign = -sign\\n29:         n += 2\\n30: \\n31:     return round(total, digits)\\n32: \\n33: \\n34: if __name__ == \\"__main__\\":\\n35:     greeting()\\n36:     print(calculate_pi())\\n37: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Both files are in place.\n\n**`main.py`** — added `calculate_pi(digits=5)` below the existing `greeting()` function:\n- Uses the **Nilakantha series** (`pi = 3 + 4/(2·3·4) − 4/(4·5·6) + 4/(6·7·8) − …`), which converges much faster than Leibniz.\n- Loops until a term drops below `10^-(digits+3)`, giving three guard digits of headroom before rounding, so the 5th decimal is reliable.\n- Rounds to `digits` places and raises `ValueError` on negative input.\n- Running `python main.py` prints the greeting and `3.14159`.\n\n**`test.py`** — a `unittest` suite covering:\n- The default call and explicit `calculate_pi(5)` both equal `3.14159`.\n- Lower precisions (0–4 digits) round correctly.\n- A `subTest` loop comparing output against `round(math.pi, d)` for 0–7 digits.\n- `ValueError` on negative digits.\n\nRun the tests with `python test.py` (or `python -m unittest test`).\n\nTwo notes on things I ran into and a caveat worth flagging:\n\n- The `insert` command errored out with `'new_str'` (it appears to require a parameter it shouldn't), so I appended the function using `str_replace` instead. Same result, just a different route.\n- I wasn't able to actually execute the code — I only have file view/create/edit access, no shell. So the tests are written but unverified; please run them to confirm. I'm confident in the math, but the guard-digit tolerance for larger `digits` values is the spot I'd watch, since float64 runs out of precision somewhere around 15 significant digits. The test only goes to 7 digits for that reason; pushing much past that would need `decimal` or a different algorithm.", type='text')]}]
