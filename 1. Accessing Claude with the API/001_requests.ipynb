# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.4.0)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anthropic) (4.15.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anthropic) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anthropic) (2.13.5)
# Requirement already satisfied: sniffio<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/javier.cervantes/Library/Python/3.14/lib/python/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.19)
# Requirement already satisfied: httpcore2==2.12.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx2<3,>=2.0.0->anthropic) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.4)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Make a request
message = client.messages.create(
  model=model,
  max_tokens=1000,
  messages=[
    {
      "role": "user",
      "content": "What is quantum computing? Answer in one sentence."
    }
  ]
)

# %%
message
# Out:
# Message(id='msg_011CevD8o29xRNnFtn9kA9zA', container=None, content=[TextBlock(citations=None, text='Quantum computing is a type of computation that harnesses quantum mechanical phenomena, such as superposition and entanglement, to process information in ways that can solve certain complex problems far faster than classical computers.', type='text')], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=17, output_tokens=44, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
message.content[0].text
# Out:
# 'Quantum computing is a type of computation that uses quantum mechanical phenomena, such as superposition and entanglement, to process information in ways that can solve certain complex problems much faster than classical computers.'

# %%
message = client.messages.create(
  model=model,
  max_tokens=1000,
  messages=[
    {
      "role": "user",
      "content": "Write another sentence"
    }
  ]
)

# %%
message.content[0].text
# Out:
# "Could you provide more context? I'd be happy to write another sentence, but I need to know:\n\n- **What topic** or subject?\n- **What style** (formal, casual, creative, etc.)?\n- Is it a continuation of something you've already written?\n\nShare some details and I'll help! 😊"

# %%
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)


def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)


def chat(messages):
  message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
  )

  return message.content[0].text

# %%
# Make a starting list of messages
messages= []

# Add in the initial user question of "Define quantum computing in one sentence"
add_user_message(messages, "Define quantum computing in one sentence")

# Pass the list of messages into 'chat' to get an answer
answer = chat(messages)

# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Write another sentence")

# Call chat again with the list of messages to get a final answer
answer = chat(messages)

answer
# Out:
# 'Unlike classical computers that store information as binary bits (0s and 1s), quantum computers use quantum bits, or **qubits**, which can exist in multiple states simultaneously, enabling them to perform many calculations at once.'

# %%
# Chat Exercise

# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
  # Get user input
  user_input = input("> ")
  print("> ", user_input)

  # Add user input to the list of messages
  add_user_message(messages, user_input)

  # Call Claude with the 'chat' function
  answer = chat(messages)

  # Add generated text to the list of messages
  add_assistant_message(messages, answer)

  # Print the generated text
  print("---")
  print(answer)
  print("---")
# Out:
# >  Explain Claude Code in one sentence
# Claude Code is an agentic coding tool by Anthropic that lets developers interact with Claude directly in their terminal to write, edit, debug, and execute code across entire codebases.
# >  Only in their terminals?
# No, Claude Code can also be integrated into other environments beyond the terminal, including IDEs and applications via the API, though the terminal/CLI is its primary and most prominent interface.
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[14], line 16
#      12   # Add user input to the list of messages
#      13   add_user_message(messages, user_input)
#      14
#      15   # Call Claude with the 'chat' function
# ---> 16   answer = chat(messages)
#      17
#      18   # Add generated text to the list of messages
#      19   add_assistant_message(messages, answer)
#
# Cell In[12], line 12, in chat(messages)
#      11 def chat(messages):
# ---> 12   message = client.messages.create(
#      13     model=model,
#      14     max_tokens=1000,
#      15     messages=messages,
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:980, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, workspace_id, extra_headers, extra_query, extra_body, timeout)
#     965     warnings.warn(
#     966         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     967         UserWarning,
#     968         stacklevel=3,
#     969     )
#     971 extra_headers = {
#     972     **strip_not_given(
#     973         {
#    (...)    978     **(extra_headers or {}),
#     979 }
# --> 980 return self._post(
#     981     "/v1/messages",
#     982     body=maybe_transform(
#     983         {
#     984             "max_tokens": max_tokens,
#     985             "messages": messages,
#     986             "model": model,
#     987             "cache_control": cache_control,
#     988             "container": container,
#     989             "inference_geo": inference_geo,
#     990             "metadata": metadata,
#     991             "output_config": output_config,
#     992             "service_tier": service_tier,
#     993             "stop_sequences": stop_sequences,
#     994             "stream": stream,
#     995             "system": system,
#     996             "thinking": thinking,
#     997             "tool_choice": tool_choice,
#     998             "tools": tools,
#     999         },
#    1000         message_create_params.MessageCreateParamsStreaming
#    1001         if stream
#    1002         else message_create_params.MessageCreateParamsNonStreaming,
#    1003     ),
#    1004     options=make_request_options(
#    1005         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1006     ),
#    1007     cast_to=Message,
#    1008     stream=stream or False,
#    1009     stream_cls=Stream[RawMessageStreamEvent],
#    1010 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/anthropic/_base_client.py:1507, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1503     raise TypeError("Passing both `files` and `content` is not supported")
#    1504 opts = FinalRequestOptions.construct(
#    1505     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1506 )
# -> 1507 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/anthropic/_base_client.py:1191, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1188     if not response.is_closed:
#    1189         response.read()
# -> 1191     raise self._make_status_error_from_response(response) from None
#    1193 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.4: user messages must have non-empty content'}, 'request_id': 'req_011CetUMybVPaoibyY71kVUh'}
